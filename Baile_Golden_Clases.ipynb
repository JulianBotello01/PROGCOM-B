# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianBotello01/PROGCOM-B/blob/main/Baile_Golden_Clases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Coreografia:

    def paso_1_cadera(self, a, b):
        for i in range(a):
            print("Muevo la cadera hacia la derecha")
        for i in range(a):
            print("Muevo la cadera hacia la izquierda")

    def paso_1_brazos(self, a):
        if a == 1:
            print("Levantar los brazos hacia arriba")
        elif a == 2:
            print("Levantar los brazos hacia arriba a la derecha")
        elif a == 3:
            print("Levantar los brazos hacia arriba a la izquierda")

    def paso_2(self, a):
        for i in range(a):
            print("Levanta las manos hacia arriba")

    def paso_3(self, a):
        for i in range(a):
            print("Pasa las manos por debajo de la quijada")

    def paso_4(self, a, b):
        for i in range(a):
            print("Se agacha")
        for i in range(b):
            print("Mueve los dos brazos levantándolos hacia los lados")

    def paso_5(self, a):
        for i in range(a):
            print("Realiza un giro")

    def paso_6(self, a):
        for i in range(a):
            print("Da un paso hacia atrás")

    def paso_7(self, a):
        for i in range(a):
            print("Flexiona las rodillas")

    def paso_8(self, a):
        for i in range(a):
            print("Extiende los brazos hacia adelante")

    def paso_9(self, a):
        for i in range(a):
            print("Extiende los brazos hacia los lados")

    def paso_10(self, a):
        for i in range(a):
            print("Lleva los brazos detrás de la cabeza")

    def paso_11(self, a):
        for i in range(a):
            print("Inclina el torso hacia adelante")

    def paso_12(self, a):
        for i in range(a):
            print("Inclina el torso hacia atrás")

    def paso_13(self, a):
        for i in range(a):
            print("Lleva brazos hacia abajo")

    def paso_14(self, a):
        for i in range(a):
            print("Lleva brazos hacia los hombros")

    def paso_15(self, direccion):
        if direccion == 1:
            print("Camina hacia la izquierda")
        elif direccion == 2:
            print("Camina hacia la derecha")
        else:
            print("Gira y vuelve al centro")

    def paso_final(self):
        print("bailarina 1 levanta los brazos hacia la derecha")
        print("bailarina 3 levanta los brazos hacia la izquierda")
        print("bailarina 1 levanta los brazos hacia la derecha en forma de L")
        print("bailarina 3 levanta los brazos hacia la izquierda en forma de L")
        print("La bailarina 1 mueve su cuerpo y extiende el brazo a la izquierda")
        print("La bailarina 3 mueve su cuerpo y extiende el brazo a la derecha")
        print("La bailarina 1 mueve su cuerpo y levanta el codo a la derecha")
        print("La bailarina 3 mueve su cuerpo y levanta el codo a la izquierda")
        print("Bailarina 1 y 3 extienden los brazos al centro formando una flecha hacia arriba")
        print("Bailarina 1 y 3 dan un paso adelante")
        print("Bailarinas cruzan los brazos hacia la derecha")
        print("Bailarinas rotan el antebrazo derecho")
        print("Bailarinas giran el brazo izquierdo en el sentido opuesto de las agujas del reloj")
        print("Bailarina 1 levanta los brazos")
        print("Bailarina 3 extiende los brazos hacia abajo")
        print("Bailarina 1 y 3 cambian la posición de sus brazos")
        print("Bailarinas extienden los brazos hacia los lados")
        print("Bailarinas estiran los brazos arriba a la derecha")
        print("Bailarinas mueven los brazos hacia la izquierda")
        print("Bailarina 1 da un paso a la izquierda y uno al frente")
        print("Bailarina 3 da un paso a la derecha y uno atrás")
        print("Bailarinas rotan el cuerpo hacia la derecha")
        print("Bailarina 3 extiende los brazos a los lados")
        print("Bailarina 1 cruza los brazos")
        print("Proceden a hacer pasos indescriptibles 🤭")

    # Baile completo en orden
    def baile_completo(self):
        self.paso_1_cadera(2, 3)
        self.paso_1_brazos(1)
        self.paso_2(1)
        self.paso_3(1)
        self.paso_4(1, 1)
        self.paso_5(1)
        self.paso_6(1)
        self.paso_7(1)
        self.paso_8(1)
        self.paso_9(1)
        self.paso_10(1)
        self.paso_11(1)
        self.paso_12(1)
        self.paso_13(1)
        self.paso_14(1)
        self.paso_15(1)
        self.paso_final()


# --- EJECUCIÓN ---
baile = Coreografia()
baile.baile_completo()
