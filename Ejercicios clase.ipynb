# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianBotello01/PROGCOM-B/blob/main/Ejercicios%20clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calcular_area_rectangulo(base, altura):
    # Esta función oculta el cálculo interno del área
    return base * altura

# Programa principal
base = float(input("Ingresa la base del rectángulo: "))
altura = float(input("Ingresa la altura del rectángulo: "))

print("El área del rectángulo es:", calcular_area_rectangulo(base, altura))

# %%
def celsius_a_fahrenheit(c):
    return (c * 9/5) + 32

def fahrenheit_a_celsius(f):
    return (f - 32) * 5/9

# Uso de las funciones
c = float(input("Temperatura en °C: "))
print("Equivale a:", celsius_a_fahrenheit(c), "°F")

# %%
def calcular_tiempo(distancia, velocidad):
    return distancia / velocidad

# Programa principal
distancia = float(input("Distancia (km): "))
velocidad = float(input("Velocidad promedio (km/h): "))

print("Tiempo estimado de viaje:", calcular_tiempo(distancia, velocidad), "horas")

# %%
class CuentaBancaria:
    def __init__(self, titular, saldo=0):
        self.titular = titular
        self.saldo = saldo

    def depositar(self, cantidad):
        self.saldo += cantidad

    def retirar(self, cantidad):
        if cantidad <= self.saldo:
            self.saldo -= cantidad
        else:
            print("Fondos insuficientes")

    def mostrar_saldo(self):
        print(f"Saldo de {self.titular}: ${self.saldo}")

# Ejemplo de uso
cuenta = CuentaBancaria("Ana", 100)
cuenta.depositar(50)
cuenta.retirar(30)
cuenta.mostrar_saldo()

# %%
def calcular(operacion, a, b):
    if operacion == "suma":
        return a + b
    elif operacion == "resta":
        return a - b
    elif operacion == "multiplicacion":
        return a * b
    elif operacion == "division":
        return a / b
    else:
        return "Operación no válida"

# Ejemplo de uso
print(calcular("suma", 4, 5))
print(calcular("division", 10, 2))
