# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianBotello01/PROGCOM-B/blob/main/Ejercicio_1_presentacion_de_JASON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
serial.onDataReceived(serial.delimiters(Delimiters.NewLine), function () {
    a = serial.readUntil(serial.delimiters(Delimiters.NewLine))
    if (a == "Led encendido") {
        basic.showIcon(IconNames.Yes)
    } else if (a == "Led apagado") {
        basic.showIcon(IconNames.No)
    }
})
let a = ""
serial.redirect(
SerialPin.P1,
SerialPin.P2,
BaudRate.BaudRate115200
)
basic.showIcon(IconNames.No)
